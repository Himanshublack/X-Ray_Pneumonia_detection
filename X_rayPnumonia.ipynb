# %%
import re
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

try:
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
  print("Devices: ", tpu.master())
except:
  strategy = tf.distribute.get_strategy()
print("Number of replicas: ", strategy.num_replicas_in_sync)
# Out:
# Number of replicas:  1

# %%
AUTOTUNE = tf.data.AUTOTUNE
BATCH_SIZE = 25*strategy.num_replicas_in_sync
IMAGE_SIZE = [180, 180]
CLASS_NAME = ["NORMAL", "PNEUMONIA"]

# %%
train_images = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/train/images.tfrec"
)
train_paths = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/train/paths.tfrec"
)

ds = tf.data.Dataset.zip((train_images, train_paths))

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
COUNT_NORMAL = len(
    [
        filename
        for filename in train_paths
        if "NORMAL" in filename.numpy().decode("utf-8")
    ]
)
print("Normal images count in training set: " + str(COUNT_NORMAL))


COUNT_PNEUMONIA = len(
    [
        filename
        for filename in train_paths
        if "PNEUMONIA" in filename.numpy().decode("utf-8")
    ]
)
print("Normal images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1349
# Normal images count in training set: 3883

# %%
def get_label(file_path):
  parts = tf.strings.split(file_path, "/")
  return parts[-2] == "PNEUMONIA"

def decode_img(img):
  img = tf.image.decode_jpeg(img, channels = 3)
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(image, path):
  label = get_label(path)
  img = decode_img(image)
  return img, label

ds = ds.map(process_path , num_parallel_calls = AUTOTUNE)

# %%
ds = ds.shuffle(10000)
train_ds = ds.take(4200)
val_ds = ds.skip(4200)

# %%
for image, label in train_ds.take(1):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  True

# %%
test_images = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/test/paths.tfrec"
)
test_paths = tf.data.TFRecordDataset(
    "gs://download.tensorflow.org/data/ChestXRay2017/test/paths.tfrec"
)

test_ds = tf.data.Dataset.zip((train_images, train_paths))
test_ds = test_ds.map(process_path, num_parallel_calls = AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)
# Out:
# path location: gs://download.tensorflow.org/data/ChestXRay2017/test/images.tfrec

# %%
def prepare_for_training(ds, cache= True):
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()

  ds = ds.batch(BATCH_SIZE)
  ds = ds.prefetch(buffer_size = AUTOTUNE)
  return ds

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

image_batch, label_batch = next(iter(train_ds))

# %%
def show_batch(image_batch, label_batch):
  plt.figure(figsize = (10, 10))
  for n in range(25):
    ax = plt.subplot(5, 5, n+1)
    plt.imshow(image_batch[n]/225)
    if label_batch[n]:
      plt.title("PNEUMONIA")
    else:
      plt.title("NORMAL")
      plt.axis("off")

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from tensorflow import keras
from tensorflow.keras import layers

def conv_block(filters, inputs):
  x = layers.SeparableConv2D(filters, 3, activation= "relu", padding= "same")(inputs)
  x = layers.SeparableConv2D(filters, 3, activation= "relu", padding ="same")(x)
  x = layers.BatchNormalization()(x)
  outputs = layers.MaxPool2D()(x)
  return outputs

def dense_block(units, dropout_rate, inputs):
  x = layers.Dense(units, activation="relu")(inputs)
  x = layers.BatchNormalization()(x)
  outputs = layers.Dropout(dropout_rate)(x)
  return outputs

# %%
def build_model():
  inputs = keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

  x = layers.Rescaling(1.0/225)(inputs)
  x = layers.Conv2D(16, 3, activation= "relu", padding="same")(x)
  #x = layers.Conv2D(16, 3, activation= "relu", padding="same")(x)
  x = layers.MaxPool2D()(x)

  x = conv_block(32, x)
  x = conv_block(64, x)

  x = conv_block(128, x)
  x = layers.Dropout(0.2)(x)

  x = conv_block(256, x)
  x = layers.Dropout(0.2)(x)

  x = layers.Flatten()(x)
  x = dense_block(512, 0.7, x)
  x = dense_block(256, 0.5, x)
  x = dense_block(64, 0.3, x)

  outputs = layers.Dense(1, activation = "sigmoid")(x)

  model = keras.Model(inputs = inputs, outputs = outputs)
  return model

# %%
initial_bias = np.log([COUNT_PNEUMONIA/COUNT_NORMAL])
print("Initial bias: {:.5f}".format(initial_bias[0]))

TRAIN_IMG_COUNT = COUNT_NORMAL + COUNT_PNEUMONIA
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print("Weight for class 0: {:.2f}".format(weight_for_0))
print("Weight for class 1: {:.2f}".format(weight_for_1))
# Out:
# Initial bias: 1.05724
# Weight for class 0: 1.94
# Weight for class 1: 0.67

# %%
# training the model

# %%
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("xray_model.h5", save_best_only = True)
early_stopping_cb = tf.keras.callbacks.EarlyStopping(
    patience = 10, restore_best_weights=True
)

# %%
initial_learning_rate = 0.015
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps = 100000, decay_rate= 0.96, staircase = True
)

# %%
with strategy.scope():
  model = build_model()
  METRICS = [
      tf.keras.metrics.BinaryAccuracy(),
      tf.keras.metrics.Precision(name = "precision"),
      tf.keras.metrics.Recall(name = "recall")
  ]
  model.compile(
      optimizer = tf.keras.optimizers.Adam(learning_rate = lr_schedule),
      loss = "binary_crossentropy",
      metrics = METRICS,
  )

history = model.fit(
    train_ds,
    epochs = 100,
    validation_data= val_ds,
    class_weight = class_weight,
    callbacks = [checkpoint_cb, early_stopping_cb],
)
# Out:
# Epoch 1/100
# 168/168 [==============================] - 338s 2s/step - loss: 0.5081 - binary_accuracy: 0.7621 - precision: 0.9054 - recall: 0.7597 - val_loss: 1.5693 - val_binary_accuracy: 0.7393 - val_precision: 0.7393 - val_recall: 1.0000
# Epoch 2/100
# 168/168 [==============================] - 226s 1s/step - loss: 0.2841 - binary_accuracy: 0.8774 - precision: 0.9608 - recall: 0.8707 - val_loss: 1.5565 - val_binary_accuracy: 0.7112 - val_precision: 0.9957 - val_recall: 0.6121
# Epoch 3/100
# 168/168 [==============================] - 218s 1s/step - loss: 0.2083 - binary_accuracy: 0.9133 - precision: 0.9720 - recall: 0.9098 - val_loss: 95.5772 - val_binary_accuracy: 0.7393 - val_precision: 0.7393 - val_recall: 1.0000
# Epoch 4/100
# 168/168 [==============================] - 225s 1s/step - loss: 0.2433 - binary_accuracy: 0.8986 - precision: 0.9658 - recall: 0.8954 - val_loss: 0.2870 - val_binary_accuracy: 0.9041 - val_precision: 0.9784 - val_recall: 0.8899
# Epoch 5/100
# 168/168 [==============================] - 217s 1s/step - loss: 0.1922 - binary_accuracy: 0.9221 - precision: 0.9736 - recall: 0.9203 - val_loss: 0.2513 - val_binary_accuracy: 0.8963 - val_precision: 0.9985 - val_recall: 0.8611
# Epoch 6/100
# 168/168 [==============================] - 218s 1s/step - loss: 0.1808 - binary_accuracy: 0.9300 - precision: 0.9758 - recall: 0.9290 - val_loss: 0.1752 - val_binary_accuracy: 0.9225 - val_precision: 0.9080 - val_recall: 0.9961
# Epoch 7/100
# 168/168 [==============================] - 219s 1s/step - loss: 0.1791 - binary_accuracy: 0.9319 - precision: 0.9791 - recall: 0.9283 - val_loss: 0.5563 - val_binary_accuracy: 0.8081 - val_precision: 0.9982 - val_recall: 0.7418
# Epoch 8/100
# 168/168 [==============================] - 221s 1s/step - loss: 0.1763 - binary_accuracy: 0.9326 - precision: 0.9785 - recall: 0.9299 - val_loss: 0.1049 - val_binary_accuracy: 0.9593 - val_precision: 0.9905 - val_recall: 0.9541
# Epoch 9/100
# 168/168 [==============================] - 210s 1s/step - loss: 0.1574 - binary_accuracy: 0.9390 - precision: 0.9806 - recall: 0.9366 - val_loss: 0.3156 - val_binary_accuracy: 0.8934 - val_precision: 1.0000 - val_recall: 0.8558
# Epoch 10/100
# 168/168 [==============================] - 222s 1s/step - loss: 0.1478 - binary_accuracy: 0.9426 - precision: 0.9800 - recall: 0.9421 - val_loss: 0.1945 - val_binary_accuracy: 0.9293 - val_precision: 0.9971 - val_recall: 0.9069
# Epoch 11/100
# 168/168 [==============================] - 211s 1s/step - loss: 0.1377 - binary_accuracy: 0.9474 - precision: 0.9824 - recall: 0.9462 - val_loss: 0.1381 - val_binary_accuracy: 0.9516 - val_precision: 0.9931 - val_recall: 0.9410
# Epoch 12/100
# 168/168 [==============================] - 217s 1s/step - loss: 0.1535 - binary_accuracy: 0.9443 - precision: 0.9820 - recall: 0.9424 - val_loss: 0.1232 - val_binary_accuracy: 0.9554 - val_precision: 0.9812 - val_recall: 0.9581
# Epoch 13/100
# 168/168 [==============================] - 219s 1s/step - loss: 0.1250 - binary_accuracy: 0.9531 - precision: 0.9861 - recall: 0.9504 - val_loss: 0.1061 - val_binary_accuracy: 0.9612 - val_precision: 0.9713 - val_recall: 0.9764
# Epoch 14/100
# 168/168 [==============================] - 217s 1s/step - loss: 0.1516 - binary_accuracy: 0.9486 - precision: 0.9834 - recall: 0.9469 - val_loss: 0.5907 - val_binary_accuracy: 0.9360 - val_precision: 0.9428 - val_recall: 0.9725
# Epoch 15/100
# 168/168 [==============================] - 218s 1s/step - loss: 0.1504 - binary_accuracy: 0.9438 - precision: 0.9804 - recall: 0.9434 - val_loss: 0.1551 - val_binary_accuracy: 0.9419 - val_precision: 0.9986 - val_recall: 0.9227
# Epoch 16/100
# 168/168 [==============================] - 219s 1s/step - loss: 0.1466 - binary_accuracy: 0.9495 - precision: 0.9834 - recall: 0.9482 - val_loss: 0.3759 - val_binary_accuracy: 0.8275 - val_precision: 0.9983 - val_recall: 0.7680
# Epoch 17/100
# 168/168 [==============================] - 219s 1s/step - loss: 0.1218 - binary_accuracy: 0.9562 - precision: 0.9871 - recall: 0.9536 - val_loss: 0.0588 - val_binary_accuracy: 0.9806 - val_precision: 0.9831 - val_recall: 0.9908
# Epoch 18/100
# 168/168 [==============================] - 222s 1s/step - loss: 0.1065 - binary_accuracy: 0.9605 - precision: 0.9868 - recall: 0.9597 - val_loss: 0.0519 - val_binary_accuracy: 0.9816 - val_precision: 0.9921 - val_recall: 0.9830
# Epoch 19/100
# 168/168 [==============================] - 222s 1s/step - loss: 0.1658 - binary_accuracy: 0.9464 - precision: 0.9798 - recall: 0.9475 - val_loss: 0.1954 - val_binary_accuracy: 0.9564 - val_precision: 0.9891 - val_recall: 0.9515
# Epoch 20/100
# 168/168 [==============================] - 230s 1s/step - loss: 0.1354 - binary_accuracy: 0.9519 - precision: 0.9841 - recall: 0.9507 - val_loss: 0.0790 - val_binary_accuracy: 0.9729 - val_precision: 0.9960 - val_recall: 0.9672
# Epoch 21/100
# 168/168 [==============================] - 225s 1s/step - loss: 0.1114 - binary_accuracy: 0.9564 - precision: 0.9855 - recall: 0.9555 - val_loss: 0.0706 - val_binary_accuracy: 0.9690 - val_precision: 0.9778 - val_recall: 0.9803
# Epoch 22/100
# 168/168 [==============================] - 219s 1s/step - loss: 0.1125 - binary_accuracy: 0.9598 - precision: 0.9849 - recall: 0.9606 - val_loss: 0.1354 - val_binary_accuracy: 0.9545 - val_precision: 0.9497 - val_recall: 0.9908
# Epoch 23/100
# 168/168 [==============================] - 226s 1s/step - loss: 0.0891 - binary_accuracy: 0.9681 - precision: 0.9898 - recall: 0.9670 - val_loss: 0.1198 - val_binary_accuracy: 0.9603 - val_precision: 0.9535 - val_recall: 0.9948
# Epoch 24/100
# 168/168 [==============================] - 227s 1s/step - loss: 0.1032 - binary_accuracy: 0.9621 - precision: 0.9878 - recall: 0.9610 - val_loss: 0.0820 - val_binary_accuracy: 0.9748 - val_precision: 0.9830 - val_recall: 0.9830
# Epoch 25/100
# 168/168 [==============================] - 220s 1s/step - loss: 0.1275 - binary_accuracy: 0.9540 - precision: 0.9845 - recall: 0.9533 - val_loss: 0.2075 - val_binary_accuracy: 0.9341 - val_precision: 0.9971 - val_recall: 0.9135
# Epoch 26/100
# 168/168 [==============================] - 225s 1s/step - loss: 0.1146 - binary_accuracy: 0.9617 - precision: 0.9859 - recall: 0.9622 - val_loss: 0.0674 - val_binary_accuracy: 0.9700 - val_precision: 0.9946 - val_recall: 0.9646
# Epoch 27/100
# 168/168 [==============================] - 225s 1s/step - loss: 0.1177 - binary_accuracy: 0.9610 - precision: 0.9872 - recall: 0.9600 - val_loss: 0.0727 - val_binary_accuracy: 0.9777 - val_precision: 0.9731 - val_recall: 0.9974
# Epoch 28/100
# 168/168 [==============================] - 218s 1s/step - loss: 0.0870 - binary_accuracy: 0.9683 - precision: 0.9898 - recall: 0.9674 - val_loss: 0.0847 - val_binary_accuracy: 0.9671 - val_precision: 0.9973 - val_recall: 0.9581

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(["precision", "recall", "binary_accuracy", "loss"]):
  ax[i].plot(history.history[met])
  ax[i].plot(history.history["val_" + met])
  ax[i].set_title("Model {}".format(met))
  ax[i].set_xlabel("epochs")
  ax[i].set_ylabel(met)
  ax[i].legend(["train", "val"])

# %%
model.evaluate(test_ds, return_dict = True)
# Out:
# 210/210 [==============================] - 109s 516ms/step - loss: 0.0647 - binary_accuracy: 0.9771 - precision: 0.9838 - recall: 0.9853
# {'loss': 0.06465466320514679,
#  'binary_accuracy': 0.9770641922950745,
#  'precision': 0.98380047082901,
#  'recall': 0.9853206276893616}

# %%
image_input = input("Put an Image : " )
for image in image_input:
  plt.imshow(image_input) #show an image depricated(image/255.0)
  #plt.title(CLASS_NAME[label[0].numpy()])

prediction = model.predict(image_input[1]) #test_ds.take(1)[]
scores = [1 - prediction, prediction]

for score, name in zip(scores, CLASS_NAME):
  print("This image is %.2f percent %s" % ((100* score), name))
# Out:
# Put an Image : 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-3585a357ed02> in <cell line: 2>()
#       1 image_input = input("Put an Image : " )
#       2 for image in image_input:
# ----> 3   plt.imshow(image_input) #show an image depricated(image/255.0)
#       4   #plt.title(CLASS_NAME[label[0].numpy()])
#       5
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# -> 2695     __ret = gca().imshow(
#    2696         X, cmap=cmap, norm=norm, aspect=aspect,
#    2697         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5663                               **kwargs)
#    5664
# -> 5665         im.set_data(X)
#    5666         im.set_alpha(alpha)
#    5667         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/image.py in set_data(self, A)
#     699         if (self._A.dtype != np.uint8 and
#     700                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 701             raise TypeError("Image data of dtype {} cannot be converted to "
#     702                             "float".format(self._A.dtype))
#     703
#
# TypeError: Image data of dtype <U1 cannot be converted to float

# %%
# import tables
# Out:
# Enter the number: 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-2dae59197f3d> in <cell line: 2>()
#       1 image_inp = int(input("Enter the number: "))
#       2 for image, label in test_ds.take(1):
# ----> 3   plt.imshow(image_inp/ 225.0)
#       4
#       5 prediction = model.predict(test_ds.take(1))[image_inp]
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# -> 2695     __ret = gca().imshow(
#    2696         X, cmap=cmap, norm=norm, aspect=aspect,
#    2697         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5663                               **kwargs)
#    5664
# -> 5665         im.set_data(X)
#    5666         im.set_alpha(alpha)
#    5667         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/image.py in set_data(self, A)
#     708         if not (self._A.ndim == 2
#     709                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 710             raise TypeError("Invalid shape {} for image data"
#     711                             .format(self._A.shape))
#     712
#
# TypeError: Invalid shape () for image data

# %%
# def get_h5_file():
#   h5_file = tables.open_file("/content/xray_model.h5")
#   return h5_file

# %%
# from .h5 import get_h5_file
# def my_view(request):
#   h5_file = get_h5_file()
#   h5_file.close()

# %%
# !pip install h5py

# %%
# from .h5 import get_h5_file
# def my_view(request):
#   h5_file = get_h5_file()
#   h5_file.close()

# %%
# import os
# import zipfile
# from google.colab import files

# def download_folder(folder_path):
#     # Get the name of the folder
#     folder_name = os.path.basename(folder_path)
#     # Create a temporary ZIP file
#     zip_path = "/tmp/{}.zip".format(folder_name)
#     with zipfile.ZipFile(zip_path, mode="w") as zipf:
#         # Add all files in the folder to the ZIP file
#         for root, dirs, files in os.walk(folder_path):
#             for file in files:
#                 file_path = os.path.join(root, file)
#                 zipf.write(file_path, os.path.relpath(file_path, folder_path))
#     # Download the ZIP file
#     files.download(zip_path)

# download_folder("/content/xray_model.joblib")
